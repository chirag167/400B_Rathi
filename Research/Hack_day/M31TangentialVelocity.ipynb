# %% [markdown]
# # Orbital Interaction Scenarios from different measurements of M31's Tangential Velocity.
#
# One of the open questions that I am interested in pursuing is the affect of M31's tangential velocity on the future interaction of the Milky Way and Andromeda. However, in my proposal I did not outline the details of the variation in tangential velocity. Here are some of the tangential velocity measurements that I am thinking of using:
#
# |Velocity (km/s) | Reference                           |
# |----------------| ----------------------------------- |
# |100             | Loeb et al. [(2005)](https://iopscience.iop.org/article/10.1086/491644)                   |
# |57              | van der Marel et al. [(2019)](https://arxiv.org/abs/1805.04079)         |
# |165             | Salomon et al. [(2016)](https://academic.oup.com/mnras/article/456/4/4432/2892320)        |
# |56              | van der Marel & Guhathakurta [(2008)](https://iopscience.iop.org/article/10.1086/533430/meta)  |
# |17              | Sohn, Anderson & van der Marel [(2012)](https://ui.adsabs.harvard.edu/abs/2012ApJ...753....8V/abstract)|
#
# NOTE: The theoretical models suggest that the tangntial velocity of M31 must be less than 200 km/s.
#
# The two figures below are taken from Loeb et al. [(2008)](https://arxiv.org/abs/0705.1170). Firstly, I plan to produce a similar graph using the tangential velocity measurement from the most recent Gaia Data Release (v = 57 km/s).
# ![Seperation.jpg](attachment:Seperation.jpg)
#
# Then, with the help of the code (developed in class) and the different measurements of tangential velocity (tabulated above), I hope to produce a plot akin to the one below:
# ![Different_models.jpg](attachment:Different_models.jpg)

# %%
# Function that takes in the different values of tangential velocity (v_tan) and computes the future orbits of
# the M31-MW systems. Will be doing an analytical integration.

# Will be requiring the Leap Frog Integrator developed in HW-7. 
# However, need to figure out a way to incorporate the tangential velocity values into the Integrator.
